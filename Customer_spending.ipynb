# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
# 5    536365     22752  ...    17850.0  United Kingdom
# 6    536365     21730  ...    17850.0  United Kingdom
# 7    536366     22633  ...    17850.0  United Kingdom
# 8    536366     22632  ...    17850.0  United Kingdom
# 9    536367     84879  ...    13047.0  United Kingdom
#
# [10 rows x 8 columns]

# %%
n = int(input("Enter number of data points to be iterated upon.\nFor all data points, enter 0. "))
if n == 0: n = sheet.max_row + 1
# Out:
# Enter number of data points to be iterated upon.
# For all data points, enter 0. 1000

# %%
customerID_list = [17850]
low_spend = []
medium_spend = []
high_spend = []
discounts = []

# %%
# sheet.max_row + 1
for row in range(2, n):
  flag = False
  for customer in customerID_list: 
    if sheet["G" + str(row)].value == customer: flag = True
  if flag == False: customerID_list.append(sheet["G" + str(row)].value)
  
print('The customer list is: ' + str(customerID_list))
print('Total number of of customers in the selected data set : ' + str(len(customerID_list)))
# Out:
# The customer list is: [17850, 13047, 12583, 13748, 15100, 15291, 14688, 17809, 15311, 14527, 16098, 18074, 17420, 16029, 16250, 12431, 17511, 17548, 13705, 13747, 13408, 13767, 17924, 13448, 15862, 15513, 12791, 16218, 14045, 14307, 17908, 17920, None, 12838, 13255, 16583, 18085, 13758, 13694, 15983, 14849, 17968, 16210, 17897, 17377, 16552, 17181, 17951, 14729]
# Total number of of customers in the selected data set : 49

# %%
for customer in customerID_list:
  customer_spending = 0
  for row in range(2, n):
    if sheet["G" + str(row)].value == customer: customer_spending += sheet["F" + str(row)].value * sheet["D" + str(row)].value
  if customer_spending > 0 and customer_spending <=500: low_spend.append(customer)
  elif customer_spending > 500 and customer_spending <=1000: medium_spend.append(customer)
  elif customer_spending > 1000: high_spend.append(customer)
  else: discounts.append(customer)

  if customer_spending > 0: print('Customer ID: ' + str(customer) + ' spent £ ' + str(abs(round(customer_spending, 2))))
  elif customer_spending < 0: print('Customer ID: ' + str(customer) + ' got a gift voucher of £ ' + str(abs(round(customer_spending, 2))))
  elif customer_spending == 0: print('Customer ID: ' + str(customer) + ' had no net transaction.')
# Out:
# Customer ID: 17850 spent £ 1499.34
# Customer ID: 13047 spent £ 366.63
# Customer ID: 12583 spent £ 855.86
# Customer ID: 13748 spent £ 204.0
# Customer ID: 15100 spent £ 350.4
# Customer ID: 15291 spent £ 328.8
# Customer ID: 14688 spent £ 444.98
# Customer ID: 17809 spent £ 34.8
# Customer ID: 15311 spent £ 445.33
# Customer ID: 14527 got a gift voucher of £ 27.5
# Customer ID: 16098 spent £ 430.6
# Customer ID: 18074 spent £ 489.6
# Customer ID: 17420 spent £ 130.85
# Customer ID: 16029 spent £ 3702.12
# Customer ID: 16250 spent £ 226.14
# Customer ID: 12431 spent £ 358.25
# Customer ID: 17511 spent £ 1825.74
# Customer ID: 17548 got a gift voucher of £ 141.48
# Customer ID: 13705 spent £ 318.14
# Customer ID: 13747 spent £ 79.6
# Customer ID: 13408 spent £ 1024.68
# Customer ID: 13767 spent £ 507.88
# Customer ID: 17924 spent £ 279.0
# Customer ID: 13448 spent £ 443.96
# Customer ID: 15862 spent £ 354.23
# Customer ID: 15513 spent £ 357.0
# Customer ID: 12791 spent £ 192.6
# Customer ID: 16218 spent £ 471.3
# Customer ID: 14045 spent £ 326.4
# Customer ID: 14307 spent £ 783.11
# Customer ID: 17908 spent £ 243.28
# Customer ID: 17920 spent £ 514.41
# Customer ID: None had no net transaction.
# Customer ID: 12838 spent £ 390.79
# Customer ID: 13255 spent £ 225.7
# Customer ID: 16583 spent £ 233.45
# Customer ID: 18085 spent £ 303.9
# Customer ID: 13758 spent £ 362.45
# Customer ID: 13694 spent £ 842.12
# Customer ID: 15983 spent £ 440.89
# Customer ID: 14849 spent £ 355.84
# Customer ID: 17968 spent £ 277.35
# Customer ID: 16210 spent £ 2474.74
# Customer ID: 17897 spent £ 140.39
# Customer ID: 17377 spent £ 223.9
# Customer ID: 16552 spent £ 95.29
# Customer ID: 17181 spent £ 155.52
# Customer ID: 17951 spent £ 295.5
# Customer ID: 14729 spent £ 263.32

# %%
print("Number of 'Low' spending customers are: " + str(len(low_spend)) + '\nTheir IDs are: ')
for i in low_spend: print(str(i) + ', ', end='')
print("\n\nNumber of 'Medium' spending customers are: " + str(len(medium_spend)) + '\nTheir IDs are: ')
for i in medium_spend: print(str(i) + ', ', end='')
print("\n\nNumber of 'High' spending customers are: " + str(len(high_spend)) + '\nTheir IDs are: ')
for i in high_spend: print(str(i) + ', ', end='')
print("\n\nNumber of customers who recieved a 'Discount' are: " + str(len(discounts)) + '\nTheir IDs are: ')
for i in discounts: print(str(i) + ', ', end='')
# Out:
# Number of 'Low' spending customers are: 36
# Their IDs are:
# 13047, 13748, 15100, 15291, 14688, 17809, 15311, 16098, 18074, 17420, 16250, 12431, 13705, 13747, 17924, 13448, 15862, 15513, 12791, 16218, 14045, 17908, 12838, 13255, 16583, 18085, 13758, 15983, 14849, 17968, 17897, 17377, 16552, 17181, 17951, 14729,
#
# Number of 'Medium' spending customers are: 5
# Their IDs are:
# 12583, 13767, 14307, 17920, 13694,
#
# Number of 'High' spending customers are: 5
# Their IDs are:
# 17850, 16029, 17511, 13408, 16210,
#
# Number of customers who recieved a 'Discount' are: 3
# Their IDs are:
# 14527, 17548, None,
